# %%
#load dataset
import pandas as pd
df = pd.read_csv('DoctorVisits.csv')
df
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0              1       1  female  0.19    0.55        1        4       1
# 1              2       1  female  0.19    0.45        1        2       1
# 2              3       1    male  0.19    0.90        3        0       0
# 3              4       1    male  0.19    0.15        1        0       0
# 4              5       1    male  0.19    0.45        2        5       1
# ...          ...     ...     ...   ...     ...      ...      ...     ...
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# ...

# %%
df.head(20)
# Out:
#     Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 0            1       1  female  0.19    0.55        1        4       1
# 1            2       1  female  0.19    0.45        1        2       1
# 2            3       1    male  0.19    0.90        3        0       0
# 3            4       1    male  0.19    0.15        1        0       0
# 4            5       1    male  0.19    0.45        2        5       1
# 5            6       1  female  0.19    0.35        5        1       9
# 6            7       1  female  0.19    0.55        4        0       2
# 7            8       1  female  0.19    0.15        3        0       6
# 8            9       1  female  0.19    0.65        2        0       5
# 9           10       1    male  0.19    0.15        1        0       0
# 10          11       1    male  0.19    0.45        1        0       0
# 11          12       1    male  0.19    0.25        2        0       2
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  visits  gender   age  income  illness  reduced  health  \
# 5185        5186       0  female  0.22    0.55        0        0       0
# 5186        5187       0    male  0.27    1.30        0        0       1
# 5187        5188       0  female  0.37    0.25        1        0       1
# 5188        5189       0  female  0.52    0.65        0        0       0
# 5189        5190       0    male  0.72    0.25        0        0       0
#
#      private freepoor freerepat nchronic lchronic
# 5185      no       no        no       no       no
# 5186      no       no        no       no       no
# 5187      no       no       yes       no       no
# 5188      no       no        no       no       no
# 5189      no       no       yes       no       no

# %%
df.describe()
# Out:
#         Unnamed: 0       visits          age       income      illness  \
# count  5190.000000  5190.000000  5190.000000  5190.000000  5190.000000
# mean   2595.500000     0.301734     0.406385     0.583160     1.431985
# std    1498.368279     0.798134     0.204782     0.368907     1.384152
# min       1.000000     0.000000     0.190000     0.000000     0.000000
# 25%    1298.250000     0.000000     0.220000     0.250000     0.000000
# 50%    2595.500000     0.000000     0.320000     0.550000     1.000000
# 75%    3892.750000     0.000000     0.620000     0.900000     2.000000
# max    5190.000000     9.000000     0.720000     1.500000     5.000000
#
#            reduced       health
# count  5190.000000  5190.000000
# mean      0.861850     1.217534
# std       2.887628     2.124266
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     2.000000
# max      14.000000    12.000000

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'visits', 'gender', 'age', 'income', 'illness', 'reduced',
#        'health', 'private', 'freepoor', 'freerepat', 'nchronic', 'lchronic'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
df['illness'].value_counts()
# Out:
# 1    1638
# 0    1554
# 2     946
# 3     542
# 4     274
# 5     236
# Name: illness, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# female    2702
# male      2488
# Name: gender, dtype: int64

# %%
import matplotlib.pyplot as plt
#visualizing
a=list(df['income'])
# a=df['income']
plt.boxplot(a)
plt.show()

# %%
#finding correlation between attributes
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),cbar=True,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
# Calculate the proportion of different health statuses
health_status_counts = df['health'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(health_status_counts.values, labels=health_status_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Health Status')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.bar(health_status_counts.index, health_status_counts.values)
plt.xlabel('Health Status')
plt.ylabel('Count')
plt.title('Distribution of Health Status')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #groupby

# %%
df.groupby(['gender','reduced']).mean()
# Out:
#                  Unnamed: 0    visits       age    income   illness    health
# gender reduced
# female 0        2524.038512  0.229322  0.465755  0.482735  1.462144  1.115098
#        1        1985.768421  0.400000  0.325684  0.542105  2.242105  1.610526
#        2        1622.618182  0.672727  0.391455  0.560182  2.236364  1.781818
#        3         997.311111  1.333333  0.403111  0.516000  2.733333  1.733333
#        4        1237.740741  0.851852  0.458889  0.466667  2.222222  2.074074
#        5        1169.055556  1.444444  0.401667  0.614444  2.222222  2.500000
#        6        1382.545455  1.363636  0.426364  0.622727  2.363636  1.363636
#        7        1034.846154  1.384615  0.436154  0.473462  2.653846  2.230769
#        8        1883.090909  1.090909  0.471818  0.404545  2.181818  4.000000
#        9        1349.000000  0.500000  0.570000  0.825000  3.000000  1.000000
#        10       1099.428571  2.142857  0.512857  0.421429  2.571429  2.000000
# ...

# %%
df['reduced'].unique()
# Out:
# array([ 4,  2,  0,  5,  1, 13,  7,  3, 14,  6,  8,  9, 10, 12, 11],
#       dtype=int64)

# %%
import seaborn as sns
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# between visit and reduced activity
plt.figure(figsize=(12,12))
plt.scatter(x= 'reduced',y='visits',data=df)
plt.xlabel('reduced')
plt.ylabel('visits')
plt.show()

# %%
plt.figure(figsize=(12,12))
plt.scatter(x= 'income',y='visits',data=df)
plt.xlabel('income')
plt.ylabel('visits')
plt.show()

# %%
#no of males and females effected by illness
sns.histplot(df.gender,bins=3)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='Count'>

# %%
# %of people getting govt health insurance due to low income
label = ['yes','no']
y = df[df['freepoor']=='yes']
n = df[df['freepoor']=='no']
x = [y.shape[0],n.shape[0]]
plt.figure(figsize =(5,5))
plt.pie(x,labels = label)
plt.title('%of people getting govt health insurance due to low income')
plt.show()
# %of people getting govt health insurance due to low income
label = ['yes','no']
y = df[df['private']=='yes']
n = df[df['private']=='no']
x = [y.shape[0],n.shape[0]]
plt.figure(figsize =(5,5))
plt.pie(x,labels = label)
plt.title('%of people getting private health insurance')
plt.show()
# %of people getting govt health insurance due to low income
label = ['yes','no']
y = df[df['freerepat']=='yes']
n = df[df['freerepat']=='no']
x = [y.shape[0],n.shape[0]]
plt.figure(figsize =(5,5))
plt.pie(x,labels = label)
plt.title('%of people getting health insurnace due to old age,disability,veterans')
plt.show()

# %%
#Plotting the bar chart to analyze the reduced days of activity due to illness based on gender
db = df.groupby('gender')['reduced'].sum().to_frame().reset_index()
plt.barh(db['gender'],db['reduced'],color = ['red','green'])
plt.title('bar chart')
plt.ylabel('gender')
plt.xlabel('reduced activity')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5190 entries, 0 to 5189
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5190 non-null   int64
#  1   visits      5190 non-null   int64
#  2   gender      5190 non-null   object
#  3   age         5190 non-null   float64
#  4   income      5190 non-null   float64
#  5   illness     5190 non-null   int64
#  6   reduced     5190 non-null   int64
#  7   health      5190 non-null   int64
#  8   private     5190 non-null   object
#  9   freepoor    5190 non-null   object
#  10  freerepat   5190 non-null   object
#  11  nchronic    5190 non-null   object
#  12  lchronic    5190 non-null   object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 527.2+ KB

# %%
# Counts of illness and chronic conditions
illness_counts = df['illness'].value_counts()
chronic_counts = df[['nchronic', 'lchronic']].apply(pd.Series.value_counts)

# Create a stacked bar chart
labels = ['No Illness', 'Illness 1', 'Illness 2', 'Illness 3', 'Illness 4', 'Illness 5']

illness_values = [illness_counts.get(0, 0), illness_counts.get(1, 0), illness_counts.get(2, 0), illness_counts.get(3, 0),
                  illness_counts.get(4, 0), illness_counts.get(5, 0)]

non_chronic_values = [0, chronic_counts.loc['no'].get('yes', 0), chronic_counts.loc['no'].get('no', 0),
                      chronic_counts.loc['no'].get('no', 0), chronic_counts.loc['no'].get('no', 0),
                      chronic_counts.loc['no'].get('no', 0)]

long_term_chronic_values = [0, chronic_counts.loc['yes'].get('yes', 0), chronic_counts.loc['no'].get('yes', 0),
                            chronic_counts.loc['no'].get('yes', 0), chronic_counts.loc['no'].get('yes', 0),
                            chronic_counts.loc['no'].get('yes', 0)]

plt.bar(labels, illness_values, label='illness')
plt.bar(labels, non_chronic_values, bottom=illness_values, label='Non-Chronic')
plt.bar(labels, long_term_chronic_values, bottom=[sum(x) for x in zip(illness_values, non_chronic_values)],
        label='Long-Term Chronic')

plt.xlabel('Condition')
plt.ylabel('Count')
plt.title('Counts of Illness and Chronic Conditions')
plt.legend()
plt.show()

# %%
df['illness'].unique()
# Out:
# array([1, 3, 2, 5, 4, 0], dtype=int64)

# %%
# Overall health status distribution
health_status_counts = df['health'].value_counts()

# Relationship between health status and gender
health_by_gender = df.groupby('gender')['health'].mean()

# Relationship between health status and age groups
age_groups = pd.cut(df['age'], bins=[0, 20, 30, 40, 50, 60, 70, 80])
health_by_age = df.groupby(age_groups)['health'].mean()

# Relationship between health status and income
income_groups = pd.cut(df['income'], bins=[0, 0.5, 1, 1.5])
health_by_income = df.groupby(income_groups)['health'].mean()

# Relationship between health status and chronic conditions
health_by_chronic_conditions = df.groupby(['nchronic', 'lchronic'])['health'].mean()

# %%
plt.bar(health_status_counts.index, health_status_counts.values)
plt.xlabel('Health Status')
plt.ylabel('Count')
plt.title('Overall Health Status Distribution')
plt.show()

# %%
# Overall health status distribution
sns.countplot(data=df, x='health')
plt.title('Overall Health Status Distribution')
# Out:
# Text(0.5, 1.0, 'Overall Health Status Distribution')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='age', hue='nchronic')
plt.title('Prevalence of Chronic Conditions by Age Group')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='age', hue='lchronic')
plt.title('Prevalence of Chronic Conditions by Age Group')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Disparities in health status
health_status_disparities = df.groupby('gender')['health'].mean()
health_status_disparities.plot(kind='bar', xlabel='Gender', ylabel='Health Status', title='Average Health Status by Gender')

plt.show()
